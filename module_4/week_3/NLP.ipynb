# %% [markdown]
# <font face="serif" size="6" color="scarlet">Natural Language Processing</font>
#
# It is a field in machine learning/deep learning that deals with understanding, analyzing, manipulating and generating language. Humans communicate through language on multiple mediums these days. It gets complicated. There is context, intonation, inflection and body language. The first major advancement in machine language processing was in 1950 when Alan Turing published "Computing Machinery and Intelligence". This paper establsihed the Turing Test, a criterion for how well a computer could impersonate a human. In 1957, Noam Chomsky's paper on Syntactic Structures revolutionized our understanding of linguistics. But a few decades passed without any real progress. It wasn't until the late 80's when ML algorithms were introduced that NLP showed real promise.
#
#  <font face="script" size="4">"Learn a language and you'll avoid a war"-Arab proverb</font>
#
#
# _NLP is not Neuro-linguistic programming(pseuodo-science - think changing behavior through hypnosis). Natural Language Understanding is similar to NLP but a bit different. NLP focuses on turning unstructured data into structured data. NLU is focused on content or sentiment analysis._

# %% [markdown]
# <font face="script" size="6" color="scarlet">NLP in the Real World</font>
#
#  Lots of everyday things we take for granted rely completely on NLP to function. Spell check and auto-complete, voice recognition/texting, spam filters, search engines, Siri/Alexa, google translate.
#
#  - [AI having a convo](https://youtu.be/WnzlbyTZsQY)
#  - [Summarize text](https://smmry.com/)
#  - [Jennings vs. Watson](https://www.ted.com/talks/ken_jennings_watson_jeopardy_and_me_the_obsolete_know_it_all)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline 

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/amberyandow/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv('job_scrape6.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 4 columns):
# title          537 non-null object
# company        520 non-null object
# location       520 non-null object
# description    537 non-null object
# dtypes: object(4)
# memory usage: 16.9+ KB

# %%
df.head()
# Out:
#                                                title            company  \
# 0                                     Data Scientist          Harmonize
# 1  Google Cloud - Business Intelligence Data Analyst          SELLBYTEL
# 2                                     Data Scientist      Fanatics Inc.
# 3             Data Analyst, YouTube Trust and Safety          SELLBYTEL
# 4      Social Health Data Analyst - Community Health  Kaiser Permanente
#
#             location                                        description
# 0  San Francisco, CA  [    Harmonize is a turnkey population health ...
# 1      Sunnyvale, CA  [     Google via The SELLBYTEL Group – Sunnyva...
# 2      San Mateo, CA  [      Company Overview        Fanatics is the...
# 3      San Bruno, CA  [    YouTube's user base is growing and changi...
# 4        Oakland, CA  [    Have you wondered what it would be like t...

# %% [markdown]
# <font face="script" size="6" color="scarlet">Preprocessing, Feature Engineering and EDA</font>
# * Casing
# * Punctuation
# * Stop word removal
# * Tokenization
#
# * Stemming
# * Lemmatization
# * POS tagging

# %% [markdown]
# <font face="script" size="6" color="scarlet">Regular Expressions</font>
# ![](regex_cheat_sheet.png)
# <a href="https://www.debuggex.com/cheatsheet/regex/python">Regex Cheatsheet</a>

# %%
#Getting rid of upper cases. This avoids having multiple copies of the same words 
df['lower_desc'] = df['description'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['lower_desc'].head()
# Out:
# 0    [ harmonize is a turnkey population health sol...
# 1    [ google via the sellbytel group – sunnyvale, ...
# 2    [ company overview fanatics is the global lead...
# 3    [ youtube's user base is growing and changing,...
# 4    [ have you wondered what it would be like to w...
# Name: lower_desc, dtype: object

# %%
#Removing punctuation. It helps us reduce the size of the data 
df['lower_desc'] = df['lower_desc'].str.replace('[^\w\s]','')
df['lower_desc'].head()
# Out:
# 0     harmonize is a turnkey population health solu...
# 1     google via the sellbytel group  sunnyvale ca ...
# 2     company overview fanatics is the global leade...
# 3     youtubes user base is growing and changing wh...
# 4     have you wondered what it would be like to wa...
# Name: lower_desc, dtype: object

# %% [markdown]
# <font face="serif" size="4">**Stop Words Removal** - words that don't contribute to the significance or meaning of a document </font>

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
print(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
df['char_count'] = df['description'].str.len() #how many characters do we have in description? 
df[['description','char_count']].head()
# Out:
#                                          description  char_count
# 0  [    Harmonize is a turnkey population health ...        1881
# 1  [     Google via The SELLBYTEL Group – Sunnyva...        3511
# 2  [      Company Overview        Fanatics is the...        6063
# 3  [    YouTube's user base is growing and changi...        2773
# 4  [    Have you wondered what it would be like t...        4532

# %%
#how many stop words do we have? 
df['stopwords'] = df['description'].apply(lambda x: len([x for x in x.split() if x in stop]))
df[['description','stopwords']].head(10)
# Out:
#                                          description  stopwords
# 0  [    Harmonize is a turnkey population health ...         64
# 1  [     Google via The SELLBYTEL Group – Sunnyva...        177
# 2  [      Company Overview        Fanatics is the...        241
# 3  [    YouTube's user base is growing and changi...        129
# 4  [    Have you wondered what it would be like t...        154
# 5  [    Job:  Engineering   Primary Location:  Un...         99
# 6  [  The Position     GENERAL POSITION SUMMARY/P...        202
# 7  [    Description:    Provides strategic leader...        121
# 8  [  --------------  About the Team  -----------...        248
# 9  [    Reporting directly to the US CRO, the Hea...        102

# %%
#removing stopwords 
df['lower_desc'] = df['lower_desc'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['lower_desc'].head()
# Out:
# 0    harmonize turnkey population health solution p...
# 1    google via sellbytel group sunnyvale ca google...
# 2    company overview fanatics global leader licens...
# 3    youtubes user base growing changing presents u...
# 4    wondered would like wake every day contribute ...
# Name: lower_desc, dtype: object

# %%
#most frequent and least frequent words 
freq = pd.Series(' '.join(df['lower_desc']).split()).value_counts()[:20]
freq
# Out:
# data           5350
# experience     2382
# business       1414
# work           1367
# skills         1158
# team           1094
# analysis        951
# years           828
# ability         824
# analytics       808
# science         761
# management      687
# including       681
# knowledge       667
# information     654
# learning        634
# development     632
# strong          615
# support         590
# job             590
# dtype: int64

# %%
df.head()
# Out:
#                                                title            company  \
# 0                                     Data Scientist          Harmonize
# 1  Google Cloud - Business Intelligence Data Analyst          SELLBYTEL
# 2                                     Data Scientist      Fanatics Inc.
# 3             Data Analyst, YouTube Trust and Safety          SELLBYTEL
# 4      Social Health Data Analyst - Community Health  Kaiser Permanente
#
#             location                                        description  \
# 0  San Francisco, CA  [    Harmonize is a turnkey population health ...
# 1      Sunnyvale, CA  [     Google via The SELLBYTEL Group – Sunnyva...
# 2      San Mateo, CA  [      Company Overview        Fanatics is the...
# 3      San Bruno, CA  [    YouTube's user base is growing and changi...
# 4        Oakland, CA  [    Have you wondered what it would be like t...
#
#                                           lower_desc  char_count  stopwords
# 0  harmonize turnkey population health solution p...        1881         64
# 1  google via sellbytel group sunnyvale ca google...        3511        177
# 2  company overview fanatics global leader licens...        6063        241
# 3  youtubes user base growing changing presents u...        2773        129
# 4  wondered would like wake every day contribute ...        4532        154

# %% [markdown]
# <font face="script" size="6" color="scarlet">Tokenization</font>

# %%
desc_str = ' '.join(df['lower_desc'].tolist())
print(desc_str)
# Out:
# harmonize turnkey population health solution provides remote patient monitoring alert triaging physicians utilize robust data help make efficient decisions provide effective care patient harmonize medical groups outsource population health teams remote patient monitoring without making changes current infrastructure looking data scientist help us discover information hidden vast amounts data help us make smarter decisions deliver even better products primary focus applying data mining techniques statistical analysis building high quality prediction systems integrated product responsibilities selecting features building optimizing classifiers using machine learning techniques enhancing data collection procedures include information relevant building analytic systems processing cleansing verifying integrity data used analysis adhoc analysis presenting results clear manner creating automated anomaly detection systems constant tracking performance requirements excellent understanding machine learning techniques algorithms knn naive bayes svm decision forests etc experience common data science toolkits great communication skills experience data visualisation tools d3js ggplot etc proficiency using query languages sql hive pig experience nosql databases mongodb cassandra hbase good applied statistics skills distributions statistical testing regression etc good scripting programming skills dataoriented personality location san francisco ca interested send resume infoharmonizehealth google via sellbytel group sunnyvale ca google cloud customer team helping customers transform evolve business use googles global data center software assets shaping future technology used workplace invite part entrepreneurial team rapidly growing business role business intelligence data analyst use technology insight business acumen creativity team builds data pipelines tools automate reporting generate insight member sales ops team use debugging skills ensure analyst teams using right data role youll building scalable solutions help make data relevant cloud current historical performance course correcting solutions based feedback proactive error handling using strong technical skills build tools automate reporting dashboard updates cloud leadership team see quickly accurately businesses performing youll involved defining user requirements building amp maintaining data infrastructure designing reports amp ensuring timely delivery end users responsibilities build data pipelines associated customer activity product usage bookings forecasting business productivity bug fixing pipelines provide insights business analysis bookings activity product data drive greater efficiency effectiveness sales teams develop bi data warehousing reporting solutions address growing business reporting analytics data requirements digging questions stakeholders data incorrect coming satisfactory solutions single source truth working teams sales team activity reports product adoption territory segment analysis minimum requirements bs degree 3 years work experience etl analyst highly analytical role experience analyzing data creating reports database query experience eg sql statistical quantitative modeling deep understanding data issues fix excellent written verbal communication skills ability work us employer provide visa sponsorship preferred requirements experience sql visualization tools capable backend data processing work necessary power uis excellent analytical problem solving skills combined strong business judgment ability present analysis clear compelling manner additional notes resumes without professional sql experience considered provide visa sponsorship c2c transfers nonlocal resumes require cover letter mentioning availability interviews remote telecommute role resumes longer two pages company sellbytel group global outsourcing company specializing sales service support human resources training back office trusted partner google promotion google cloud related product ...

# %%
tokens = nltk.word_tokenize(desc_str) #tokenizing 
print(len(tokens))
# Out:
# 177181

# %% [markdown]
# <font face="script" size="6" color="scarlet">Stemming</font>
# - a technique to remove affixes from a word and ending up with the stem. Play would be the stem of a word and the 'ing' in playing would be an affix. This process makes similar words more equal to each other. This way the algorithm only has to learn the stem of the word instead of the stem and all its variants.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer 
porter = PorterStemmer() #instantiate
lemma = WordNetLemmatizer() #instantiate

# %%
print(porter.stem("I studied physics"))
# Out:
# i studied phys

# %% [markdown]
# <font face="script" size="6" color="scarlet">Lemmatization</font>
# - similar to stemming but it brings context to the words with morphological(words relationships to other words) analysis. A lemma is the base form of all its inflectional forms. Inflections are added to the stem of a word

# %%
print(lemma.lemmatize("physics"))
# Out:
# physic

# %% [markdown]
# <font face="script" size="6" color="scarlet">POS Tagging</font>

# %%
tokens_pos = nltk.pos_tag(tokens)
pos_df = pd.DataFrame(tokens_pos, columns = ('word','POS'))
pos_sum = pos_df.groupby('POS', as_index=False).count() # group by POS tags
pos_sum.sort_values(['word'], ascending=[False]) # in descending order of number of words per tag
# Out:
#      POS   word
# 10    NN  64245
# 13   NNS  35249
# 6     JJ  31162
# 27   VBP  11124
# 25   VBG  10939
# 17    RB   4638
# 24   VBD   3441
# 26   VBN   3189
# 2     CD   2832
# 23    VB   2803
# 28   VBZ   2796
# 5     IN   1935
# 9     MD    605
# 8    JJS    502
# 15   PRP    476
# 4     FW    255
# 1     CC    239
# 18   RBR    225
# 7    JJR    223
# 3     DT    139
# 11   NNP     52
# 20    RP     28
# 19   RBS     24
# 30   WP$     19
# 29   WDT     11
# 31   WRB      9
# 0      $      7
# 22    UH      4
# 16  PRP$      4
# 21    TO      2
# 14   POS      2
# 12  NNPS      2

# %%
#getting just the nouns
filtered_pos = [ ]
for one in tokens_pos:
    if one[1] == 'NN' or one[1] == 'NNS' or one[1] == 'NNP' or one[1] == 'NNPS':
        filtered_pos.append(one)
print (len(filtered_pos))
# Out:
# 99548

# %%
#the 100 most common nouns
fdist_pos = nltk.FreqDist(filtered_pos)
top_100_words = fdist_pos.most_common(100)
print(top_100_words)
# Out:
# [(('data', 'NNS'), 5006), (('experience', 'NN'), 1906), (('business', 'NN'), 1414), (('skills', 'NNS'), 1090), (('work', 'NN'), 1052), (('team', 'NN'), 970), (('analysis', 'NN'), 925), (('years', 'NNS'), 828), (('ability', 'NN'), 824), (('analytics', 'NNS'), 802), (('science', 'NN'), 757), (('management', 'NN'), 687), (('information', 'NN'), 654), (('development', 'NN'), 632), (('job', 'NN'), 590), (('solutions', 'NNS'), 574), (('research', 'NN'), 565), (('status', 'NN'), 524), (('opportunity', 'NN'), 496), (('models', 'NNS'), 475), (('knowledge', 'NN'), 475), (('support', 'NN'), 473), (('machine', 'NN'), 467), (('analyst', 'NN'), 464), (('position', 'NN'), 423), (('health', 'NN'), 420), (('tools', 'NNS'), 409), (('reports', 'NNS'), 406), (('requirements', 'NNS'), 387), (('company', 'NN'), 386), (('projects', 'NNS'), 382), (('environment', 'NN'), 371), (('systems', 'NNS'), 370), (('product', 'NN'), 369), (('insights', 'NNS'), 362), (('quality', 'NN'), 357), (('teams', 'NNS'), 346), (('responsibilities', 'NNS'), 344), (('qualifications', 'NNS'), 342), (('techniques', 'NNS'), 340), (('people', 'NNS'), 340), (('opportunities', 'NNS'), 339), (('computer', 'NN'), 338), (('technology', 'NN'), 326), (('problems', 'NNS'), 326), (('customer', 'NN'), 325), (('statistics', 'NNS'), 321), (('communication', 'NN'), 317), (('project', 'NN'), 317), (('risk', 'NN'), 317), (('role', 'NN'), 310), (('software', 'NN'), 305), (('time', 'NN'), 303), (('insurance', 'NN'), 299), (('results', 'NNS'), 298), (('engineering', 'NN'), 289), (('clients', 'NNS'), 288), (('services', 'NNS'), 288), (('field', 'NN'), 285), (('process', 'NN'), 285), (('companies', 'NNS'), 279), (('customers', 'NNS'), 278), (('design', 'NN'), 277), (('employment', 'NN'), 276), (('benefits', 'NNS'), 273), (('disability', 'NN'), 267), (('products', 'NNS'), 265), (('gender', 'NN'), 253), (('employer', 'NN'), 251), (('operations', 'NNS'), 244), (('bachelors', 'NNS'), 244), (('technologies', 'NNS'), 243), (('sql', 'NN'), 241), (('industry', 'NN'), 240), (('location', 'NN'), 237), (('python', 'NN'), 235), (('r', 'NN'), 217), (('marketing', 'NN'), 215), (('orientation', 'NN'), 215), (('visualization', 'NN'), 212), (('system', 'NN'), 207), (('sets', 'NNS'), 206), (('application', 'NN'), 205), (('applicants', 'NNS'), 205), (('scientist', 'NN'), 204), (('performance', 'NN'), 204), (('race', 'NN'), 203), (('religion', 'NN'), 203), (('stakeholders', 'NNS'), 202), (('veteran', 'NN'), 202), (('help', 'NN'), 199), (('use', 'NN'), 198), (('color', 'NN'), 195), (('sources', 'NNS'), 194), (('origin', 'NN'), 193), (('identity', 'NN'), 192), (('leadership', 'NN'), 187), (('issues', 'NNS'), 187), (('world', 'NN'), 187), (('database', 'NN'), 183)]

# %%
top_words_df = pd.DataFrame(top_100_words, columns = ('pos','count'))
top_words_df['Word'] = top_words_df['pos'].apply(lambda x: x[0]) # split the tuple of POS
top_words_df = top_words_df.drop('pos', 1) # drop the previous column
top_words_df.head(10)
# Out:
#    count        Word
# 0   5006        data
# 1   1906  experience
# 2   1414    business
# 3   1090      skills
# 4   1052        work
# 5    970        team
# 6    925    analysis
# 7    828       years
# 8    824     ability
# 9    802   analytics

# %%
fig, ax = plt.subplots(figsize=(15,18))
top_words_df.sort_values(by='count').plot.barh(x='Word',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in DS Job Descriptions(Without Stop Words)")

plt.show()

# %%
from textblob import TextBlob, Word
from wordcloud import WordCloud

# %%
word_counts = ' '.join(top_words_df['Word'].tolist())
print(type(word_counts))
# Out:
# <class 'str'>

# %%
wordcloud = WordCloud().generate(word_counts)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# <center><img src="tfidf.png" height=600 width=600>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df['lower_desc'].head()
# Out:
# 0    harmonize turnkey population health solution p...
# 1    google via sellbytel group sunnyvale ca google...
# 2    company overview fanatics global leader licens...
# 3    youtubes user base growing changing presents u...
# 4    wondered would like wake every day contribute ...
# Name: lower_desc, dtype: object

# %% [markdown]
# Transform text into a bag of words. CountVectorizer learns from the text with the fit method and then transforms the text into a list of lists(a matrix).

# %%
from sklearn.feature_extraction import text
vectorizer = text.CountVectorizer().fit(df.lower_desc)
vectorized_text = vectorizer.transform(df.lower_desc)
print(vectorized_text.todense()[-1])
# Out:
# [[0 0 0 ... 0 0 0]]

# %% [markdown]
# We must normalize the text length.

# %%
TfidF = text.TfidfTransformer(norm='l1')
tfidf = TfidF.fit_transform(vectorized_text)

phrase = 3 #choose 0-3
total = 0

# %% [markdown]
# This TF-IDF model rescales the values of important words and makes them comparable between each text in the corpus

# %%
print(vectorizer.vocabulary_)
# Out:
# {'harmonize': 4081, 'turnkey': 8987, 'population': 6613, 'health': 4103, 'solution': 8102, 'provides': 6966, 'remote': 7337, 'patient': 6374, 'monitoring': 5717, 'alert': 608, 'triaging': 8942, 'physicians': 6511, 'utilize': 9164, 'robust': 7573, 'data': 2355, 'help': 4126, 'make': 5330, 'efficient': 2971, 'decisions': 2443, 'provide': 6960, 'effective': 2964, 'care': 1463, 'medical': 5486, 'groups': 4014, 'outsource': 6257, 'teams': 8613, 'without': 9467, 'making': 5334, 'changes': 1580, 'current': 2307, 'infrastructure': 4578, 'looking': 5256, 'scientist': 7722, 'us': 9130, 'discover': 2715, 'information': 4570, 'hidden': 4148, 'vast': 9207, 'amounts': 683, 'smarter': 8062, 'deliver': 2497, 'even': 3256, 'better': 1172, 'products': 6857, 'primary': 6784, 'focus': 3634, 'applying': 804, 'mining': 5621, 'techniques': 8626, 'statistical': 8297, 'analysis': 692, 'building': 1354, 'high': 4152, 'quality': 7046, 'prediction': 6705, 'systems': 8550, 'integrated': 4674, 'product': 6844, 'responsibilities': 7450, 'selecting': 7805, 'features': 3515, 'optimizing': 6191, 'classifiers': 1669, 'using': 9154, 'machine': 5302, 'learning': 5066, 'enhancing': 3117, 'collection': 1801, 'procedures': 6824, 'include': 4475, 'relevant': 7317, 'analytic': 705, 'processing': 6831, 'cleansing': 1683, 'verifying': 9231, 'integrity': 4681, 'used': 9143, 'adhoc': 475, 'presenting': 6756, 'results': 7474, 'clear': 1686, 'manner': 5361, 'creating': 2224, 'automated': 1011, 'anomaly': 758, 'detection': 2601, 'constant': 2039, 'tracking': 8842, 'performance': 6422, 'requirements': 7393, 'excellent': 3297, 'understanding': 9042, 'algorithms': 615, 'knn': 4965, 'naive': 5815, 'bayes': 1116, 'svm': 8529, 'decision': 2438, 'forests': 3665, 'etc': 3231, 'experience': 3357, 'common': 1854, 'science': 7704, 'toolkits': 8804, 'great': 3999, 'communication': 1862, 'skills': 8024, 'visualisation': 9296, 'tools': 8805, 'd3js': 2342, 'ggplot': 3908, 'proficiency': 6869, 'query': 7066, 'languages': 5010, 'sql': 8222, 'hive': 4203, 'pig': 6523, 'nosql': 5992, 'databases': 2361, 'mongodb': 5714, 'cassandra': 1497, 'hbase': 4092, 'good': 3945, 'applied': 801, 'statistics': 8305, 'distributions': 2769, 'testing': 8687, 'regression': 7271, 'scripting': 7750, 'programming': 6889, 'dataoriented': 2376, 'personality': 6454, 'location': 5229, 'san': 7645, 'francisco': 3726, 'ca': 1392, 'interested': 4714, 'send': 7851, 'resume': 7480, 'infoharmonizehealth': 4562, 'google': 3947, 'via': 9251, 'sellbytel': 7836, 'group': 4013, 'sunnyvale': 8476, 'cloud': 1730, 'customer': 2312, 'team': 8604, 'helping': 4131, 'customers': 2319, 'transform': 8887, 'evolve': 3280, 'business': 1368, 'use': 9141, 'googles': 3948, 'global': 3929, 'center': 1545, 'software': 8093, 'assets': 916, 'shaping': 7923, 'future': 3815, 'technology': 8633, 'workplace': 9493, 'invite': 4792, 'part': 6334, 'entrepreneurial': 3152, 'rapidly': 7120, 'growing': 4018, 'role': 7579, 'intelligence': 4687, 'analyst': 701, 'insight': 4627, 'acumen': 442, 'creativity': 2230, 'builds': 1357, 'pipelines': 6539, 'automate': 1010, 'reporting': 7361, 'generate': 3868, 'member': 5502, 'sales': 7636, 'ops': 6176, 'debugging': 2429, 'ensure': 3129, 'right': 7552, 'youll': 9588, 'scalable': 7676, 'solutions': 8104, 'historical': 4196, 'course': 2196, 'correcting': 2161, 'based': 1101, 'feedback': 3522, 'proactive': 6805, 'error': 3200, 'handling': 4062, 'strong': 8390, 'technical': 8618, 'build': 1353, 'dashboard': 2350, 'updates': 9108, 'leadership': 5053, 'see': 7790, 'quickly': 7077, 'accurately': 389, 'businesses': 1372, 'performing': 6430, 'involved': 4797, 'defining': 2479, 'user': 9147, 'amp': 684, 'maintaining': 5324, 'designing': 2578, 'reports': 7363, 'ensuring': 3131, 'timely': 8770, 'delivery': 2505, 'end': 3074, 'users': 9151, 'associated': 933, 'activity': 435, 'usage': 9136, 'bookings': 1266, 'forecasting': 3657, 'productivity': 6853, 'bug': 1352, 'fixing': 3605, 'insights': 4629, 'drive': 2853, 'greater': 4000, 'ef ...

# %%
for word in vectorizer.vocabulary_:
    pos = vectorizer.vocabulary_[word]
    value = list(tfidf.toarray()[phrase])[pos]
    if value !=0:
        print("%10s: %0.3f" % (word, value))
        total += value
print('\nSummed values of a phrase: %0.1f' % total)
# Out:
#   provides: 0.007
#     remote: 0.005
#       data: 0.014
#    provide: 0.006
#  effective: 0.003
#    without: 0.003
#         us: 0.002
#   products: 0.003
#   analysis: 0.002
# responsibilities: 0.002
#  integrity: 0.010
# requirements: 0.002
# experience: 0.009
# communication: 0.002
#     skills: 0.003
#      tools: 0.004
#        sql: 0.004
#     google: 0.013
#  sellbytel: 0.008
#      group: 0.003
#       team: 0.003
#  customers: 0.003
#   business: 0.007
#     global: 0.003
#     future: 0.004
#    growing: 0.003
#       role: 0.002
#    analyst: 0.002
#  reporting: 0.008
#      sales: 0.004
#  solutions: 0.002
#  proactive: 0.005
#     strong: 0.004
#  technical: 0.004
#      build: 0.002
#       user: 0.004
#      users: 0.004
#   insights: 0.007
#      drive: 0.003
#    develop: 0.002
#  analytics: 0.002
#    working: 0.002
#     degree: 0.002
#      years: 0.002
#       work: 0.004
#  analyzing: 0.003
#     issues: 0.015
#    written: 0.003
#     verbal: 0.003
#    ability: 0.004
#   employer: 0.002
#       visa: 0.011
# sponsorship: 0.010
#  preferred: 0.002
#    problem: 0.003
# additional: 0.003
#      notes: 0.007
#    resumes: 0.015
# professional: 0.006
# considered: 0.004
#        c2c: 0.006
#  transfers: 0.006
#   nonlocal: 0.007
#    require: 0.004
#      cover: 0.006
#     letter: 0.006
# mentioning: 0.008
# availability: 0.007
# interviews: 0.006
# telecommute: 0.007
#     longer: 0.007
#        two: 0.004
#      pages: 0.008
#    company: 0.005
# outsourcing: 0.008
# specializing: 0.007
#    service: 0.003
#    support: 0.006
#      human: 0.004
#  resources: 0.004
#   training: 0.003
#       back: 0.005
#     office: 0.003
#    trusted: 0.005
#    partner: 0.004
#  promotion: 0.006
#    related: 0.004
#   changing: 0.004
# engineering: 0.003
#        one: 0.002
#       sets: 0.005
#     trends: 0.003
# opportunities: 0.002
#  providing: 0.003
# operations: 0.011
# actionable: 0.003
#        key: 0.003
#     causes: 0.006
#      field: 0.002
#   youtubes: 0.008
#       base: 0.005
#   presents: 0.006
#     unique: 0.004
# challenges: 0.008
#    billion: 0.010
#   globally: 0.006
#  fastpaced: 0.004
#    dynamic: 0.004
#    youtube: 0.037
#      trust: 0.016
#     safety: 0.016
#     scaled: 0.015
#       keep: 0.005
#       safe: 0.006
#    viewers: 0.008
#   creators: 0.008
# advertisers: 0.008
#         yt: 0.008
#    driving: 0.013
# investments: 0.006
# responsible: 0.003
# completion: 0.005
#  important: 0.004
#        set: 0.004
#   workflow: 0.005
#   aptitude: 0.006
#       able: 0.006
#     handle: 0.005
#      large: 0.005
#   facility: 0.006
#       also: 0.003
#  patiently: 0.008
# individual: 0.003
# comfortable: 0.004
# duplication: 0.008
# processessystems: 0.008
#      solve: 0.003
# commitment: 0.005
#   internal: 0.003
#   external: 0.003
#       best: 0.003
#   possible: 0.005
#   pipeline: 0.005
# dashboards: 0.004
# validation: 0.004
#   partners: 0.003
#    monitor: 0.004
#    respond: 0.006
# escalations: 0.008
#      quick: 0.013
# streamline: 0.006
#       easy: 0.006
# automation: 0.004
#       babs: 0.007
#    finance: 0.003
# equivalent: 0.003
#  practical: 0.005
#   advanced: 0.002
# spreadsheet: 0.007
# proprietary: 0.004
#  attention: 0.004
#     detail: 0.003
#      ethic: 0.007
#    dealing: 0.006
#    variety: 0.003
#      grasp: 0.007
#  structure: 0.004
#     thrive: 0.004
#    handson: 0.004
# highgrowth: 0.007
# environment: 0.002
# aggressive: 0.007
#     solver: 0.006
#    curious: 0.005
#    opposed: 0.008
#  committed: 0.003
# reproducing: 0.008
#     former: 0.007
# structures: 0.004
# relocation: 0.006
#   packages: 0.004
#       apps: 0.006
#
# Summed values of a phrase: 1.0

# %% [markdown]
# <font face="script" size="6" color="scarlet">N-Grams</font>

# %%
df.head()
# Out:
#                                                title            company  \
# 0                                     Data Scientist          Harmonize
# 1  Google Cloud - Business Intelligence Data Analyst          SELLBYTEL
# 2                                     Data Scientist      Fanatics Inc.
# 3             Data Analyst, YouTube Trust and Safety          SELLBYTEL
# 4      Social Health Data Analyst - Community Health  Kaiser Permanente
#
#             location                                        description  \
# 0  San Francisco, CA  [    Harmonize is a turnkey population health ...
# 1      Sunnyvale, CA  [     Google via The SELLBYTEL Group – Sunnyva...
# 2      San Mateo, CA  [      Company Overview        Fanatics is the...
# 3      San Bruno, CA  [    YouTube's user base is growing and changi...
# 4        Oakland, CA  [    Have you wondered what it would be like t...
#
#                                           lower_desc  char_count  stopwords
# 0  harmonize turnkey population health solution p...        1881         64
# 1  google via sellbytel group sunnyvale ca google...        3511        177
# 2  company overview fanatics global leader licens...        6063        241
# 3  youtubes user base growing changing presents u...        2773        129
# 4  wondered would like wake every day contribute ...        4532        154

# %%
TextBlob(desc_str).ngrams(2)
# Out:
# [WordList(['harmonize', 'turnkey']),
#  WordList(['turnkey', 'population']),
#  WordList(['population', 'health']),
#  WordList(['health', 'solution']),
#  WordList(['solution', 'provides']),
#  WordList(['provides', 'remote']),
#  WordList(['remote', 'patient']),
#  WordList(['patient', 'monitoring']),
#  WordList(['monitoring', 'alert']),
#  WordList(['alert', 'triaging']),
#  WordList(['triaging', 'physicians']),
#  WordList(['physicians', 'utilize']),
#  WordList(['utilize', 'robust']),
#  WordList(['robust', 'data']),
#  WordList(['data', 'help']),
#  WordList(['help', 'make']),
#  WordList(['make', 'efficient']),
#  WordList(['efficient', 'decisions']),
#  WordList(['decisions', 'provide']),
#  WordList(['provide', 'effective']),
#  WordList(['effective', 'care']),
#  WordList(['care', 'patient']),
#  WordList(['patient', 'harmonize']),
#  WordList(['harmonize', 'medical']),
#  WordList(['medical', 'groups']),
#  WordList(['groups', 'outsource']),
#  WordList(['outsource', 'population']),
#  WordList(['population', 'health']),
#  WordList(['health', 'teams']),
#  WordList(['teams', 'remote']),
#  WordList(['remote', 'patient']),
#  WordList(['patient', 'monitoring']),
#  WordList(['monitoring', 'without']),
#  WordList(['without', 'making']),
#  WordList(['making', 'changes']),
#  WordList(['changes', 'current']),
#  WordList(['current', 'infrastructure']),
#  WordList(['infrastructure', 'looking']),
#  WordList(['looking', 'data']),
#  WordList(['data', 'scientist']),
#  WordList(['scientist', 'help']),
#  WordList(['help', 'us']),
#  WordList(['us', 'discover']),
#  WordList(['discover', 'information']),
#  WordList(['information', 'hidden']),
#  WordList(['hidden', 'vast']),
#  WordList(['vast', 'amounts']),
#  WordList(['amounts', 'data']),
#  WordList(['data', 'help']),
#  WordList(['help', 'us']),
#  WordList(['us', 'make']),
#  WordList(['make', 'smarter']),
#  WordList(['smarter', 'decisions']),
#  WordList(['decisions', 'deliver']),
#  WordList(['deliver', 'even']),
#  WordList(['even', 'better']),
#  WordList(['better', 'products']),
#  WordList(['products', 'primary']),
#  WordList(['primary', 'focus']),
#  WordList(['focus', 'applying']),
#  WordList(['applying', 'data']),
#  WordList(['data', 'mining']),
#  WordList(['mining', 'techniques']),
#  WordList(['techniques', 'statistical']),
#  WordList(['statistical', 'analysis']),
#  WordList(['analysis', 'building']),
#  WordList(['building', 'high']),
#  WordList(['high', 'quality']),
#  WordList(['quality', 'prediction']),
#  WordList(['prediction', 'systems']),
#  WordList(['systems', 'integrated']),
#  WordList(['integrated', 'product']),
#  WordList(['product', 'responsibilities']),
#  WordList(['responsibilities', 'selecting']),
#  WordList(['selecting', 'features']),
#  WordList(['features', 'building']),
#  WordList(['building', 'optimizing']),
#  WordList(['optimizing', 'classifiers']),
#  WordList(['classifiers', 'using']),
#  WordList(['using', 'machine']),
#  WordList(['machine', 'learning']),
#  WordList(['learning', 'techniques']),
#  WordList(['techniques', 'enhancing']),
#  WordList(['enhancing', 'data']),
#  WordList(['data', 'collection']),
#  WordList(['collection', 'procedures']),
#  WordList(['procedures', 'include']),
#  WordList(['include', 'information']),
#  WordList(['information', 'relevant']),
#  WordList(['relevant', 'building']),
#  WordList(['building', 'analytic']),
#  WordList(['analytic', 'systems']),
#  WordList(['systems', 'processing']),
#  WordList(['processing', 'cleansing']),
#  WordList(['cleansing', 'verifying']),
#  WordList(['verifying', 'integrity']),
#  WordList(['integrity', 'data']),
#  WordList(['data', 'used']),
#  WordList(['used', 'analysis']),
#  WordList(['analysis', 'adhoc']),
#  WordList(['adhoc', 'analysis']),
#  WordList(['analysis', 'presenting']),
#  WordList(['presenting', 'results']),
#  WordList(['results', 'clear']),
#  WordList(['clear', 'manner']),
#  WordList(['manner', 'creating']),
#  WordList(['creating', 'automated']),
#  WordList(['automated', 'anomaly']),
#  WordList(['anomaly', 'detection']),
#  WordList(['detection', 'systems']),
#  WordList(['systems', 'constant']),
#  WordList(['constant', 'tracking']),
#  WordList(['tracking', 'performance']),
#  WordList(['performance', 'requirements']),
#  WordList(['requirements', 'excellent']),
#  WordList(['excellent', 'understanding']),
#  WordList(['understanding', 'machine']),
#  WordList(['machine', 'learning']),
#  WordList(['learning', 'techniques']),
#  WordList(['techniques', 'algorithms']),
#  WordList(['algorithms', 'knn']),
#  WordList(['knn', 'naive']),
#  WordList(['naive', 'bayes']),
#  WordList(['bayes', 'svm']),
#  WordList(['svm', 'decision']),
#  WordList(['decision', 'forests']),
#  WordList(['forests', 'etc']),
#  WordList(['etc', 'experience']),
#  WordList(['experience', 'common']),
#  WordList(['common', 'data']),
#  WordList(['data', 'science']),
#  WordList(['science', 'toolkits']),
#  WordList(['toolkits', 'great']),
#  WordList(['great', 'communication']),
#  WordList(['communication', 'skills']),
#  WordList(['skills', 'experience']),
#  WordList(['experience', 'data']),
#  WordList(['data', 'visualisation']),
#  WordList(['visualisation', 'tools']),
#  WordList(['tools', 'd3js']),
#  WordList(['d3js', 'ggplot']),
#  WordList(['ggplot', 'etc']),
#  WordList(['etc', 'proficiency']),
#  WordList(['proficiency', 'using']),
#  WordList(['using', 'query']),
#  WordList(['query', 'languages']),
#  WordList(['languages', 'sql']),
#  WordList(['sql', 'hive']),
#  WordList(['hive', 'pig']),
#  WordList(['pig', 'experience']),
#  WordList(['experience', 'nosql']),
#  WordList(['nosql', 'databases']),
#  WordList(['databases', 'mongodb']),
#  WordList(['mongodb', 'cassandra']),
#  WordList(['cassandra', 'hbase']),
#  WordList(['hbase', 'good']),
#  WordList(['good', 'applied']),
#  WordList(['applied', 'statistics']),
#  WordList(['statistics', 'skills']),
#  WordList(['skills', 'distributions']),
#  WordList(['distributions', 'statistical']),
#  WordList(['statistical', 'testing']),
#  WordList(['testing', 'regression']),
#  WordList(['regression', 'etc']),
#  WordList(['etc', 'good']),
#  WordList(['good', 'scripting']),
#  WordList(['scripting', 'programming']),
#  WordList(['programming', 'skills']),
#  WordList(['skills', 'dataoriented']),
#  WordList(['dataoriented', 'personality']),
#  WordList(['personality', 'location']),
#  WordList(['location', 'san']),
#  WordList(['san', 'francisco']),
#  WordList(['francisco', 'ca']),
#  WordList(['ca', 'interested']),
#  WordList(['interested', 'send']),
#  WordList(['send', 'resume']),
#  WordList(['resume', 'infoharmonizehealth']),
#  WordList(['infoharmonizehealth', 'google']),
#  WordList(['google', 'via']),
#  WordList(['via', 'sellbytel']),
#  WordList(['sellbytel', 'group']),
#  WordList(['group', 'sunnyvale']),
#  WordList(['sunnyvale', 'ca']),
#  WordList(['ca', 'google']),
#  WordList(['google', 'cloud']),
#  WordList(['cloud', 'customer']),
#  WordList(['customer', 'team']),
#  WordList(['team', 'helping']),
#  WordList(['helping', 'customers']),
#  WordList(['customers', 'transform']),
#  WordList(['transform', 'evolve']),
#  WordList(['evolve', 'business']),
#  WordList(['business', 'use']),
#  WordList(['use', 'googles']),
#  WordList(['googles', 'global']),
#  WordList(['global', 'data']),
#  WordList(['data', 'center']),
#  WordList(['center', 'software']),
#  WordList(['software', 'assets']),
#  WordList(['assets', 'shaping']),
#  WordList(['shaping', 'future']),
#  WordList(['future', 'technology']),
#  WordList(['technology', 'used']),
#  WordList(['used', 'workplace']),
#  WordList(['workplace', 'invite']),
#  WordList(['invite', 'part']),
#  WordList(['part', 'entrepreneurial']),
#  WordList(['entrepreneurial', 'team']),
#  WordList(['team', 'rapidly']),
#  WordList(['rapidly', 'growing']),
#  WordList(['growing', 'business']),
#  WordList(['business', 'role']),
#  WordList(['role', 'business']),
#  WordList(['business', 'intelligence']),
#  WordList(['intelligence', 'data']),
#  WordList(['data', 'analyst']),
#  WordList(['analyst', 'use']),
#  WordList(['use', 'technology']),
#  WordList(['technology', 'insight']),
#  WordList(['insight', 'business']),
#  WordList(['business', 'acumen']),
#  WordList(['acumen', 'creativity']),
#  WordList(['creativity', 'team']),
#  WordList(['team', 'builds']),
#  WordList(['builds', 'data']),
#  WordList(['data', 'pipelines']),
#  WordList(['pipelines', 'tools']),
#  WordList(['tools', 'automate']),
#  WordList(['automate', 'reporting']),
#  WordList(['reporting', 'generate']),
#  WordList(['generate', 'insight']),
#  WordList(['insight', 'member']),
#  WordList(['member', 'sales']),
#  WordList(['sales', 'ops']),
#  WordList(['ops', 'team']),
#  WordList(['team', 'use']),
#  WordList(['use', 'debugging']),
#  WordList(['debugging', 'skills']),
#  WordList(['skills', 'ensure']),
#  WordList(['ensure', 'analyst']),
#  WordList(['analyst', 'teams']),
#  WordList(['teams', 'using']),
#  WordList(['using', 'right']),
#  WordList(['right', 'data']),
#  WordList(['data', 'role']),
#  WordList(['role', 'youll']),
#  WordList(['youll', 'building']),
#  WordList(['building', 'scalable']),
#  WordList(['scalable', 'solutions']),
#  WordList(['solutions', 'help']),
#  WordList(['help', 'make']),
#  WordList(['make', 'data']),
#  WordList(['data', 'relevant']),
#  WordList(['relevant', 'cloud']),
#  WordList(['cloud', 'current']),
#  WordList(['current', 'historical']),
#  WordList(['historical', 'performance']),
#  WordList(['performance', 'course']),
#  WordList(['course', 'correcting']),
#  WordList(['correcting', 'solutions']),
#  WordList(['solutions', 'based']),
#  WordList(['based', 'feedback']),
#  WordList(['feedback', 'proactive']),
#  WordList(['proactive', 'error']),
#  WordList(['error', 'handling']),
#  WordList(['handling', 'using']),
#  WordList(['using', 'strong']),
#  WordList(['strong', 'technical']),
#  WordList(['technical', 'skills']),
#  WordList(['skills', 'build']),
#  WordList(['build', 'tools']),
#  WordList(['tools', 'automate']),
#  WordList(['automate', 'reporting']),
#  WordList(['reporting', 'dashboard']),
#  WordList(['dashboard', 'updates']),
#  WordList(['updates', 'cloud']),
#  WordList(['cloud', 'leadership']),
#  WordList(['leadership', 'team']),
#  WordList(['team', 'see']),
#  WordList(['see', 'quickly']),
#  WordList(['quickly', 'accurately']),
#  WordList(['accurately', 'businesses']),
#  WordList(['businesses', 'performing']),
#  WordList(['performing', 'youll']),
#  WordList(['youll', 'involved']),
#  WordList(['involved', 'defining']),
#  WordList(['defining', 'user']),
#  WordList(['user', 'requirements']),
#  WordList(['requirements', 'building']),
#  WordList(['building', 'amp']),
#  WordList(['amp', 'maintaining']),
#  WordList(['maintaining', 'data']),
#  WordList(['data', 'infrastructure']),
#  WordList(['infrastructure', 'designing']),
#  WordList(['designing', 'reports']),
#  WordList(['reports', 'amp']),
#  WordList(['amp', 'ensuring']),
#  WordList(['ensuring', 'timely']),
#  WordList(['timely', 'delivery']),
#  WordList(['delivery', 'end']),
#  WordList(['end', 'users']),
#  WordList(['users', 'responsibilities']),
#  WordList(['responsibilities', 'build']),
#  WordList(['build', 'data']),
#  WordList(['data', 'pipelines']),
#  WordList(['pipelines', 'associated']),
#  WordList(['associated', 'customer']),
#  WordList(['customer', 'activity']),
#  WordList(['activity', 'product']),
#  WordList(['product', 'usage']),
#  WordList(['usage', 'bookings']),
#  WordList(['bookings', 'forecasting']),
#  WordList(['forecasting', 'business']),
#  WordList(['business', 'productivity']),
#  WordList(['productivity', 'bug']),
#  WordList(['bug', 'fixing']),
#  WordList(['fixing', 'pipelines']),
#  WordList(['pipelines', 'provide']),
#  WordList(['provide', 'insights']),
#  WordList(['insights', 'business']),
#  WordList(['business', 'analysis']),
#  WordList(['analysis', 'bookings']),
#  WordList(['bookings', 'activity']),
#  WordList(['activity', 'product']),
#  WordList(['product', 'data']),
#  WordList(['data', 'drive']),
#  WordList(['drive', 'greater']),
#  WordList(['greater', 'efficiency']),
#  WordList(['efficiency', 'effectiveness']),
#  WordList(['effectiveness', 'sales']),
#  WordList(['sales', 'teams']),
#  WordList(['teams', 'develop']),
#  WordList(['develop', 'bi']),
#  WordList(['bi', 'data']),
#  WordList(['data', 'warehousing']),
#  WordList(['warehousing', 'reporting']),
#  WordList(['reporting', 'solutions']),
#  WordList(['solutions', 'address']),
#  WordList(['address', 'growing']),
#  WordList(['growing', 'business']),
#  WordList(['business', 'reporting']),
#  WordList(['reporting', 'analytics']),
#  WordList(['analytics', 'data']),
#  WordList(['data', 'requirements']),
#  WordList(['requirements', 'digging']),
#  WordList(['digging', 'questions']),
#  WordList(['questions', 'stakeholders']),
#  WordList(['stakeholders', 'data']),
#  WordList(['data', 'incorrect']),
#  WordList(['incorrect', 'coming']),
#  WordList(['coming', 'satisfactory']),
#  WordList(['satisfactory', 'solutions']),
#  WordList(['solutions', 'single']),
#  WordList(['single', 'source']),
#  WordList(['source', 'truth']),
#  WordList(['truth', 'working']),
#  WordList(['working', 'teams']),
#  WordList(['teams', 'sales']),
#  WordList(['sales', 'team']),
#  WordList(['team', 'activity']),
#  WordList(['activity', 'reports']),
#  WordList(['reports', 'product']),
#  WordList(['product', 'adoption']),
#  WordList(['adoption', 'territory']),
#  WordList(['territory', 'segment']),
#  WordList(['segment', 'analysis']),
#  WordList(['analysis', 'minimum']),
#  WordList(['minimum', 'requirements']),
#  WordList(['requirements', 'bs']),
#  WordList(['bs', 'degree']),
#  WordList(['degree', '3']),
#  WordList(['3', 'years']),
#  WordList(['years', 'work']),
#  WordList(['work', 'experience']),
#  WordList(['experience', 'etl']),
#  WordList(['etl', 'analyst']),
#  WordList(['analyst', 'highly']),
#  WordList(['highly', 'analytical']),
#  WordList(['analytical', 'role']),
#  WordList(['role', 'experience']),
#  WordList(['experience', 'analyzing']),
#  WordList(['analyzing', 'data']),
#  WordList(['data', 'creating']),
#  WordList(['creating', 'reports']),
#  WordList(['reports', 'database']),
#  WordList(['database', 'query']),
#  WordList(['query', 'experience']),
#  WordList(['experience', 'eg']),
#  WordList(['eg', 'sql']),
#  WordList(['sql', 'statistical']),
#  WordList(['statistical', 'quantitative']),
#  WordList(['quantitative', 'modeling']),
#  WordList(['modeling', 'deep']),
#  WordList(['deep', 'understanding']),
#  WordList(['understanding', 'data']),
#  WordList(['data', 'issues']),
#  WordList(['issues', 'fix']),
#  WordList(['fix', 'excellent']),
#  WordList(['excellent', 'written']),
#  WordList(['written', 'verbal']),
#  WordList(['verbal', 'communication']),
#  WordList(['communication', 'skills']),
#  WordList(['skills', 'ability']),
#  WordList(['ability', 'work']),
#  WordList(['work', 'us']),
#  WordList(['us', 'employer']),
#  WordList(['employer', 'provide']),
#  WordList(['provide', 'visa']),
#  WordList(['visa', 'sponsorship']),
#  WordList(['sponsorship', 'preferred']),
#  WordList(['preferred', 'requirements']),
#  WordList(['requirements', 'experience']),
#  WordList(['experience', 'sql']),
#  WordList(['sql', 'visualization']),
#  WordList(['visualization', 'tools']),
#  WordList(['tools', 'capable']),
#  WordList(['capable', 'backend']),
#  WordList(['backend', 'data']),
#  WordList(['data', 'processing']),
#  WordList(['processing', 'work']),
#  WordList(['work', 'necessary']),
#  WordList(['necessary', 'power']),
#  WordList(['power', 'uis']),
#  WordList(['uis', 'excellent']),
#  WordList(['excellent', 'analytical']),
#  WordList(['analytical', 'problem']),
#  WordList(['problem', 'solving']),
#  WordList(['solving', 'skills']),
#  WordList(['skills', 'combined']),
#  WordList(['combined', 'strong']),
#  WordList(['strong', 'business']),
#  WordList(['business', 'judgment']),
#  WordList(['judgment', 'ability']),
#  WordList(['ability', 'present']),
#  WordList(['present', 'analysis']),
#  WordList(['analysis', 'clear']),
#  WordList(['clear', 'compelling']),
#  WordList(['compelling', 'manner']),
#  WordList(['manner', 'additional']),
#  WordList(['additional', 'notes']),
#  WordList(['notes', 'resumes']),
#  WordList(['resumes', 'without']),
#  WordList(['without', 'professional']),
#  WordList(['professional', 'sql']),
#  WordList(['sql', 'experience']),
#  WordList(['experience', 'considered']),
#  WordList(['considered', 'provide']),
#  WordList(['provide', 'visa']),
#  WordList(['visa', 'sponsorship']),
#  WordList(['sponsorship', 'c2c']),
#  WordList(['c2c', 'transfers']),
#  WordList(['transfers', 'nonlocal']),
#  WordList(['nonlocal', 'resumes']),
#  WordList(['resumes', 'require']),
#  WordList(['require', 'cover']),
#  WordList(['cover', 'letter']),
#  WordList(['letter', 'mentioning']),
#  WordList(['mentioning', 'availability']),
#  WordList(['availability', 'interviews']),
#  WordList(['interviews', 'remote']),
#  WordList(['remote', 'telecommute']),
#  WordList(['telecommute', 'role']),
#  WordList(['role', 'resumes']),
#  WordList(['resumes', 'longer']),
#  WordList(['longer', 'two']),
#  WordList(['two', 'pages']),
#  WordList(['pages', 'company']),
#  WordList(['company', 'sellbytel']),
#  WordList(['sellbytel', 'group']),
#  WordList(['group', 'global']),
#  WordList(['global', 'outsourcing']),
#  WordList(['outsourcing', 'company']),
#  WordList(['company', 'specializing']),
#  WordList(['specializing', 'sales']),
#  WordList(['sales', 'service']),
#  WordList(['service', 'support']),
#  WordList(['support', 'human']),
#  WordList(['human', 'resources']),
#  WordList(['resources', 'training']),
#  WordList(['training', 'back']),
#  WordList(['back', 'office']),
#  WordList(['office', 'trusted']),
#  WordList(['trusted', 'partner']),
#  WordList(['partner', 'google']),
#  WordList(['google', 'promotion']),
#  WordList(['promotion', 'google']),
#  WordList(['google', 'cloud']),
#  WordList(['cloud', 'related']),
#  WordList(['related', 'products']),
#  WordList(['products', 'looking']),
#  WordList(['looking', 'motivated']),
#  WordList(['motivated', 'talented']),
#  WordList(['talented', 'data']),
#  WordList(['data', 'analysis']),
#  WordList(['analysis', 'professionals']),
#  WordList(['professionals', 'join']),
#  WordList(['join', 'us']),
#  WordList(['us', 'work']),
#  WordList(['work', 'google']),
#  WordList(['google', 'cloud']),
#  WordList(['cloud', 'team']),
#  WordList(['team', 'company']),
#  WordList(['company', 'overview']),
#  WordList(['overview', 'fanatics']),
#  WordList(['fanatics', 'global']),
#  WordList(['global', 'leader']),
#  WordList(['leader', 'licensed']),
#  WordList(['licensed', 'sports']),
#  WordList(['sports', 'merchandise']),
#  WordList(['merchandise', 'changing']),
#  WordList(['changing', 'way']),
#  WordList(['way', 'fans']),
#  WordList(['fans', 'purchase']),
#  WordList(['purchase', 'favorite']),
#  WordList(['favorite', 'team']),
#  WordList(['team', 'apparel']),
#  WordList(['apparel', 'jerseys']),
#  WordList(['jerseys', 'innovative']),
#  WordList(['innovative', 'techinfused']),
#  WordList(['techinfused', 'approach']),
#  WordList(['approach', 'making']),
#  WordList(['making', 'selling']),
#  WordList(['selling', 'fan']),
#  WordList(['fan', 'gear']),
#  WordList(['gear', 'todays']),
#  WordList(['todays', 'ondemand']),
#  WordList(['ondemand', 'culture']),
#  WordList(['culture', 'fanatics']),
#  WordList(['fanatics', 'operates']),
#  WordList(['operates', '300']),
#  WordList(['300', 'online']),
#  WordList(['online', 'offline']),
#  WordList(['offline', 'stores']),
#  WordList(['stores', 'including']),
#  WordList(['including', 'ecommerce']),
#  WordList(['ecommerce', 'business']),
#  WordList(['business', 'major']),
#  WordList(['major', 'professional']),
#  WordList(['professional', 'sports']),
#  WordList(['sports', 'leagues']),
#  WordList(['leagues', 'nfl']),
#  WordList(['nfl', 'mlb']),
#  WordList(['mlb', 'nba']),
#  WordList(['nba', 'nhl']),
#  WordList(['nhl', 'nascar']),
#  WordList(['nascar', 'mls']),
#  WordList(['mls', 'pga']),
#  WordList(['pga', 'major']),
#  WordList(['major', 'media']),
#  WordList(['media', 'brands']),
#  WordList(['brands', 'nbc']),
#  WordList(['nbc', 'sports']),
#  WordList(['sports', 'cbs']),
#  WordList(['cbs', 'sports']),
#  WordList(['sports', 'fox']),
#  WordList(['fox', 'sports']),
#  WordList(['sports', '200']),
#  WordList(['200', 'collegiate']),
#  WordList(['collegiate', 'professional']),
#  WordList(['professional', 'team']),
#  WordList(['team', 'properties']),
#  WordList(['properties', 'include']),
#  WordList(['include', 'several']),
#  WordList(['several', 'biggest']),
#  WordList(['biggest', 'global']),
#  WordList(['global', 'soccer']),
#  WordList(['soccer', 'clubs']),
#  WordList(['clubs', 'manchester']),
#  WordList(['manchester', 'united']),
#  WordList(['united', 'real']),
#  WordList(['real', 'madrid']),
#  WordList(['madrid', 'chelsea']),
#  WordList(['chelsea', 'manchester']),
#  WordList(['manchester', 'city']),
#  WordList(['city', 'fanatics']),
#  WordList(['fanatics', 'offers']),
#  WordList(['offers', 'largest']),
#  WordList(['largest', 'collection']),
#  WordList(['collection', 'timeless']),
#  WordList(['timeless', 'timely']),
#  WordList(['timely', 'merchandise']),
#  WordList(['merchandise', 'whether']),
#  WordList(['whether', 'shopping']),
#  WordList(['shopping', 'online']),
#  WordList(['online', 'phone']),
#  WordList(['phone', 'stores']),
#  WordList(['stores', 'stadiums']),
#  WordList(['stadiums', 'onsite']),
#  WordList(['onsite', 'worlds']),
#  WordList(['worlds', 'biggest']),
#  WordList(['biggest', 'sporting']),
#  WordList(['sporting', 'events']),
#  WordList(['events', 'team']),
#  WordList(['team', 'fanatics']),
#  WordList(['fanatics', 'first']),
#  WordList(['first', 'foremost']),
#  WordList(['foremost', 'technology']),
#  WordList(['technology', 'company']),
#  WordList(['company', 'powered']),
#  WordList(['powered', 'cuttingedge']),
#  WordList(['cuttingedge', 'tech']),
#  WordList(['tech', 'created']),
#  WordList(['created', 'small']),
#  WordList(['small', 'agile']),
#  WordList(['agile', 'teams']),
#  WordList(['teams', 'using']),
#  WordList(['using', 'latest']),
#  WordList(['latest', 'tools']),
#  WordList(['tools', 'technologies']),
#  WordList(['technologies', 'highly']),
#  WordList(['highly', 'analytical']),
#  WordList(['analytical', 'forward']),
#  WordList(['forward', 'thinking']),
#  WordList(['thinking', 'openminded']),
#  WordList(['openminded', 'leadership']),
#  WordList(['leadership', 'global']),
#  WordList(['global', 'leader']),
#  WordList(['leader', 'licensed']),
#  WordList(['licensed', 'sports']),
#  WordList(['sports', 'merchandise']),
#  WordList(['merchandise', 'challenge']),
#  WordList(['challenge', 'improving']),
#  WordList(['improving', 'new']),
#  WordList(['new', 'fully']),
#  WordList(['fully', 'responsive']),
#  WordList(['responsive', 'nodejs']),
#  WordList(['nodejs', 'cloud']),
#  WordList(['cloud', 'commerce']),
#  WordList(['commerce', 'platform']),
#  WordList(['platform', 'elasticsearch']),
#  WordList(['elasticsearch', 'engine']),
#  WordList(['engine', 'deep']),
#  WordList(['deep', 'data']),
#  WordList(['data', 'science']),
#  WordList(['science', 'capabilities']),
#  WordList(['capabilities', 'building']),
#  WordList(['building', 'bestinclass']),
#  WordList(['bestinclass', 'retail']),
#  WordList(['retail', 'manufacturing']),
#  WordList(['manufacturing', 'supply']),
#  WordList(['supply', 'chain']),
#  WordList(['chain', 'technologies']),
#  WordList(['technologies', 'tech']),
#  WordList(['tech', 'teams']),
#  WordList(['teams', 'work']),
#  WordList(['work', 'together']),
#  WordList(['together', 'revolutionize']),
#  WordList(['revolutionize', 'data']),
#  WordList(['data', 'science']),
#  WordList(['science', 'engineering']),
#  WordList(['engineering', 'initiatives']),
#  WordList(['initiatives', 'provide']),
#  WordList(['provide', 'highly']),
#  WordList(['highly', 'scalable']),
#  WordList(['scalable', 'realtime']),
#  WordList(['realtime', 'streaming']),
#  WordList(['streaming', 'platforms']),
#  WordList(['platforms', 'create']),
#  WordList(['create', 'secure']),
#  WordList(['secure', 'ecommerce']),
#  WordList(['ecommerce', 'instadium']),
#  WordList(['instadium', 'fan']),
#  WordList(['fan', 'experience']),
#  WordList(['experience', 'products']),
#  WordList(['products', 'ecommerce']),
#  WordList(['ecommerce', 'platform']),
#  WordList(['platform', 'transacts']),
#  WordList(['transacts', '190']),
#  WordList(['190', 'countries']),
#  WordList(['countries', '17']),
#  WordList(['17', 'languages']),
#  WordList(['languages', '14']),
#  WordList(['14', 'currencies']),
#  WordList(['currencies', 'motto']),
#  WordList(['motto', 'gsdget']),
#  WordList(['gsdget', 'stuff']),
#  WordList(['stuff', 'doneand']),
#  WordList(['doneand', 'want']),
#  WordList(['want', 'nexus']),
#  WordList(['nexus', 'sports']),
#  WordList(['sports', 'commerce']),
#  WordList(['commerce', 'technology']),
#  WordList(['technology', 'come']),
#  WordList(['come', 'part']),
#  WordList(['part', 'industryleading']),
#  WordList(['industryleading', 'team']),
#  WordList(['team', 'fanatics']),
#  WordList(['fanatics', 'tech']),
#  WordList(['tech', 'fanatics']),
#  WordList(['fanatics', 'global']),
#  WordList(['global', 'leader']),
#  WordList(['leader', 'licensed']),
#  WordList(['licensed', 'sports']),
#  WordList(['sports', 'merchandise']),
#  WordList(['merchandise', 'changing']),
#  WordList(['changing', 'way']),
#  WordList(['way', 'fans']),
#  WordList(['fans', 'purchase']),
#  WordList(['purchase', 'favorite']),
#  WordList(['favorite', 'team']),
#  WordList(['team', 'apparel']),
#  WordList(['apparel', 'jerseys']),
#  WordList(['jerseys', 'innovative']),
#  WordList(['innovative', 'techinfused']),
#  WordList(['techinfused', 'approach']),
#  WordList(['approach', 'making']),
#  WordList(['making', 'selling']),
#  WordList(['selling', 'fan']),
#  WordList(['fan', 'gear']),
#  WordList(['gear', 'todays']),
#  WordList(['todays', 'ondemand']),
#  WordList(['ondemand', 'culture']),
#  WordList(['culture', 'fanatics']),
#  WordList(['fanatics', 'operates']),
#  WordList(['operates', '300']),
#  WordList(['300', 'online']),
#  WordList(['online', 'offline']),
#  WordList(['offline', 'stores']),
#  WordList(['stores', 'including']),
#  WordList(['including', 'ecommerce']),
#  WordList(['ecommerce', 'business']),
#  WordList(['business', 'major']),
#  WordList(['major', 'professional']),
#  WordList(['professional', 'sports']),
#  WordList(['sports', 'leagues']),
#  WordList(['leagues', 'nfl']),
#  WordList(['nfl', 'mlb']),
#  WordList(['mlb', 'nba']),
#  WordList(['nba', 'nhl']),
#  WordList(['nhl', 'nascar']),
#  WordList(['nascar', 'mls']),
#  WordList(['mls', 'pga']),
#  WordList(['pga', 'major']),
#  WordList(['major', 'media']),
#  WordList(['media', 'brands']),
#  WordList(['brands', 'nbc']),
#  WordList(['nbc', 'sports']),
#  WordList(['sports', 'cbs']),
#  WordList(['cbs', 'sports']),
#  WordList(['sports', 'fox']),
#  WordList(['fox', 'sports']),
#  WordList(['sports', '200']),
#  WordList(['200', 'collegiate']),
#  WordList(['collegiate', 'professional']),
#  WordList(['professional', 'team']),
#  WordList(['team', 'properties']),
#  WordList(['properties', 'include']),
#  WordList(['include', 'several']),
#  WordList(['several', 'biggest']),
#  WordList(['biggest', 'global']),
#  WordList(['global', 'soccer']),
#  WordList(['soccer', 'clubs']),
#  WordList(['clubs', 'manchester']),
#  WordList(['manchester', 'united']),
#  WordList(['united', 'real']),
#  WordList(['real', 'madrid']),
#  WordList(['madrid', 'chelsea']),
#  WordList(['chelsea', 'manchester']),
#  WordList(['manchester', 'city']),
#  WordList(['city', 'fanatics']),
#  WordList(['fanatics', 'offers']),
#  WordList(['offers', 'largest']),
#  WordList(['largest', 'collection']),
#  WordList(['collection', 'timeless']),
#  WordList(['timeless', 'timely']),
#  WordList(['timely', 'merchandise']),
#  WordList(['merchandise', 'whether']),
#  WordList(['whether', 'shopping']),
#  WordList(['shopping', 'online']),
#  WordList(['online', 'phone']),
#  WordList(['phone', 'stores']),
#  WordList(['stores', 'stadiums']),
#  WordList(['stadiums', 'onsite']),
#  WordList(['onsite', 'worlds']),
#  WordList(['worlds', 'biggest']),
#  WordList(['biggest', 'sporting']),
#  WordList(['sporting', 'events']),
#  WordList(['events', 'team']),
#  WordList(['team', 'fanatics']),
#  WordList(['fanatics', 'first']),
#  WordList(['first', 'foremost']),
#  WordList(['foremost', 'technology']),
#  WordList(['technology', 'company']),
#  WordList(['company', 'powered']),
#  WordList(['powered', 'cuttingedge']),
#  WordList(['cuttingedge', 'tech']),
#  WordList(['tech', 'created']),
#  WordList(['created', 'small']),
#  WordList(['small', 'agile']),
#  WordList(['agile', 'teams']),
#  WordList(['teams', 'using']),
#  WordList(['using', 'latest']),
#  WordList(['latest', 'tools']),
#  WordList(['tools', 'technologies']),
#  WordList(['technologies', 'highly']),
#  WordList(['highly', 'analytical']),
#  WordList(['analytical', 'forward']),
#  WordList(['forward', 'thinking']),
#  WordList(['thinking', 'openminded']),
#  WordList(['openminded', 'leadership']),
#  WordList(['leadership', 'global']),
#  WordList(['global', 'leader']),
#  WordList(['leader', 'licensed']),
#  WordList(['licensed', 'sports']),
#  WordList(['sports', 'merchandise']),
#  WordList(['merchandise', 'challenge']),
#  WordList(['challenge', 'improving']),
#  WordList(['improving', 'new']),
#  WordList(['new', 'fully']),
#  WordList(['fully', 'responsive']),
#  WordList(['responsive', 'nodejs']),
#  WordList(['nodejs', 'cloud']),
#  WordList(['cloud', 'commerce']),
#  WordList(['commerce', 'platform']),
#  WordList(['platform', 'elasticsearch']),
#  WordList(['elasticsearch', 'engine']),
#  WordList(['engine', 'deep']),
#  WordList(['deep', 'data']),
#  WordList(['data', 'science']),
#  WordList(['science', 'capabilities']),
#  WordList(['capabilities', 'building']),
#  WordList(['building', 'bestinclass']),
#  WordList(['bestinclass', 'retail']),
#  WordList(['retail', 'manufacturing']),
#  WordList(['manufacturing', 'supply']),
#  WordList(['supply', 'chain']),
#  WordList(['chain', 'technologies']),
#  WordList(['technologies', 'tech']),
#  WordList(['tech', 'teams']),
#  WordList(['teams', 'work']),
#  WordList(['work', 'together']),
#  WordList(['together', 'revolutionize']),
#  WordList(['revolutionize', 'data']),
#  WordList(['data', 'science']),
#  WordList(['science', 'engineering']),
#  WordList(['engineering', 'initiatives']),
#  WordList(['initiatives', 'provide']),
#  WordList(['provide', 'highly']),
#  WordList(['highly', 'scalable']),
#  WordList(['scalable', 'realtime']),
#  WordList(['realtime', 'streaming']),
#  WordList(['streaming', 'platforms']),
#  WordList(['platforms', 'create']),
#  WordList(['create', 'secure']),
#  WordList(['secure', 'ecommerce']),
#  WordList(['ecommerce', 'instadium']),
#  WordList(['instadium', 'fan']),
#  WordList(['fan', 'experience']),
#  WordList(['experience', 'products']),
#  WordList(['products', 'ecommerce']),
#  WordList(['ecommerce', 'platform']),
#  WordList(['platform', 'transacts']),
#  WordList(['transacts', '190']),
#  WordList(['190', 'countries']),
#  WordList(['countries', '17']),
#  WordList(['17', 'languages']),
#  WordList(['languages', '14']),
#  WordList(['14', 'currencies']),
#  WordList(['currencies', 'motto']),
#  WordList(['motto', 'gsdget']),
#  WordList(['gsdget', 'stuff']),
#  WordList(['stuff', 'doneand']),
#  WordList(['doneand', 'want']),
#  WordList(['want', 'nexus']),
#  WordList(['nexus', 'sports']),
#  WordList(['sports', 'commerce']),
#  WordList(['commerce', 'technology']),
#  WordList(['technology', 'come']),
#  WordList(['come', 'part']),
#  WordList(['part', 'industryleading']),
#  WordList(['industryleading', 'team']),
#  WordList(['team', 'fanatics']),
#  WordList(['fanatics', 'tech']),
#  WordList(['tech', 'job']),
#  WordList(['job', 'description']),
#  WordList(['description', 'fanatics']),
#  WordList(['fanatics', 'passionate']),
#  WordList(['passionate', 'leveraging']),
#  WordList(['leveraging', 'data']),
#  WordList(['data', 'drive']),
#  WordList(['drive', 'growth']),
#  WordList(['growth', 'operational']),
#  WordList(['operational', 'efficiencies']),
#  WordList(['efficiencies', 'firmly']),
#  WordList(['firmly', 'believe']),
#  WordList(['believe', 'putting']),
#  WordList(['putting', 'data']),
#  WordList(['data', 'forefront']),
#  WordList(['forefront', 'delivering']),
#  WordList(['delivering', 'engaging']),
#  WordList(['engaging', 'experience']),
#  WordList(['experience', 'sports']),
#  WordList(['sports', 'fans']),
#  WordList(['fans', 'fanatics']),
#  WordList(['fanatics', 'inc']),
#  WordList(['inc', 'looking']),
#  WordList(['looking', 'highly']),
#  WordList(['highly', 'motivated']),
#  WordList(['motivated', 'individuals']),
#  WordList(['individuals', 'join']),
#  WordList(['join', 'data']),
#  WordList(['data', 'science']),
#  WordList(['science', 'engineering']),
#  WordList(['engineering', 'team']),
#  WordList(['team', 'collaborate']),
#  WordList(['collaborate', 'closely']),
#  WordList(['closely', 'engineering']),
#  WordList(['engineering', 'pms']),
#  WordList(['pms', 'cross']),
#  WordList(['cross', 'functional']),
#  WordList(['functional', 'business']),
#  WordList(['business', 'units']),
#  WordList(['units', 'address']),
#  WordList(['address', 'challenging']),
#  WordList(['challenging', 'problems']),
#  WordList(['problems', 'using']),
#  WordList(['using', 'techniques']),
#  WordList(['techniques', 'applied']),
#  WordList(['applied', 'statistics']),
#  WordList(['statistics', 'machine']),
#  WordList(['machine', 'learning']),
#  WordList(['learning', 'andor']),
#  WordList(['andor', 'data']),
#  WordList(['data', 'mining']),
#  WordList(['mining', 'fields']),
#  WordList(['fields', 'responsibilities']),
#  WordList(['responsibilities', 'build']),
#  WordList(['build', 'deploy']),
#  WordList(['deploy', 'maintain']),
#  WordList(['maintain', 'predictive']),
#  WordList(['predictive', 'models']),
#  WordList(['models', 'one']),
#  WordList(['one', 'following']),
#  WordList(['following', 'areas']),
#  WordList(['areas', '1']),
#  WordList(['1', 'price']),
#  WordList(['price', 'promotion']),
#  WordList(['promotion', 'optimization']),
#  WordList(['optimization', '2']),
#  WordList(['2', 'inventory']),
#  WordList(['inventory', 'optimization']),
#  WordList(['optimization', '3']),
#  WordList(['3', 'emarketing']),
#  WordList(['emarketing', 'optimization']),
#  WordList(['optimization', 'dive']),
#  WordList(['dive', 'complex']),
#  WordList(['complex', 'data']),
#  WordList(['data', 'sets']),
#  WordList(['sets', 'analyze']),
#  WordList(['analyze', 'trends']),
#  WordList(['trends', 'identify']),
#  WordList(['identify', 'opportunities']),
#  WordList(['opportunities', 'improvement']),
#  WordList(['improvement', 'support']),
#  WordList(['support', 'business']),
#  WordList(['business', 'stakeholders']),
#  WordList(['stakeholders', 'providing']),
#  WordList(['providing', 'adhoc']),
#  WordList(['adhoc', 'analysis']),
#  WordList(['analysis', 'help']),
#  WordList(['help', 'drive']),
#  WordList(['drive', 'decisionmaking']),
#  WordList(['decisionmaking', 'collaborate']),
#  WordList(['collaborate', 'crossfunctionally']),
#  WordList(['crossfunctionally', 'diverse']),
#  WordList(['diverse', 'teams']),
#  WordList(['teams', 'eg']),
#  WordList(['eg', 'marketing']),
#  WordList(['marketing', 'operations']),
#  WordList(['operations', 'technology']),
#  WordList(['technology', 'merchandising']),
#  WordList(['merchandising', 'procurement']),
#  WordList(['procurement', 'apparel']),
#  WordList(['apparel', 'designproduction']),
#  WordList(['designproduction', 'understand']),
#  WordList(['understand', 'business']),
#  WordList(['business', 'objectives']),
#  WordList(['objectives', 'design']),
#  WordList(['design', 'implement']),
#  WordList(['implement', 'datadriven']),
#  WordList(['datadriven', 'solutions']),
#  WordList(['solutions', 'effectively']),
#  WordList(['effectively', 'communicate']),
#  WordList(['communicate', 'analytical']),
#  WordList(['analytical', 'solutions']),
#  WordList(['solutions', 'nontechnical']),
#  WordList(['nontechnical', 'stakeholders']),
#  WordList(['stakeholders', 'senior']),
#  WordList(['senior', 'leadership']),
#  WordList(['leadership', 'qualifications']),
#  WordList(['qualifications', 'minimum']),
#  WordList(['minimum', '3']),
#  WordList(['3', 'years']),
#  WordList(['years', 'experience']),
#  WordList(['experience', 'industry']),
#  WordList(['industry', 'excluding']),
#  WordList(['excluding', 'internships']),
#  WordList(['internships', 'co']),
#  WordList(['co', 'op']),
#  ...]

# %% [markdown]
# <font face="script" size="6" color="scarlet">Resources</font>
# * [Text blob library](https://textblob.readthedocs.io/en/dev/api_reference.html#textblob.blob.Word)
#
# * [Googles n-gram viewer](https://books.google.com/ngrams/graph?content=API&year_start=1800&year_end=2010&corpus=0&smoothing=3&direct_url=t1%3B%2CAPI%3B%2Cc0)
#
# * [Tweepy - python library for accessing the Twitter API](https://www.tweepy.org/)
#
# * [Step by step guide for NLP](https://blog.insightdatascience.com/how-to-solve-90-of-nlp-problems-a-step-by-step-guide-fda605278e4e)
